# %%
import rebound
from IPython.display import display, clear_output
import matplotlib.pyplot as plt
#import ipywidgets as widgets
import numpy as np

# %%
sim = rebound.Simulation()
#sim.G = 4*np.pi**2 julian year is 365.25, while actual is 365.256
sim.G = 39.4769264214

sim.units = ['AU', 'yr', 'Msun']

date = "2019-02-28 00:00"

sim.add("Sun", date = date)
sim.add(["Mercury","Venus","Earth","Mars"])

sim.add("NAME=1986 TO", m=6.537671975029727e-17)#3753 Cruithne

sim.add(["Jupiter","Saturn","Uranus","Neptune"])
sim.move_to_com()
sim.save("28Feb.bin")

# %%
sim = rebound.Simulation.from_file("28Feb.bin")
sim.status()
# Out:
# ---------------------------------
# REBOUND version:     	3.8.0
# REBOUND built on:    	Mar  9 2019 15:06:42
# Number of particles: 	10
# Selected integrator: 	ias15
# Simulation time:     	0.0000000000000000e+00
# Current timestep:    	0.001000
# ---------------------------------
# <rebound.Particle object, m=1.0 x=-0.001220266373766985 y=0.007528113974059555 z=-4.54104691375795e-05 vx=-0.0029765930537352446 vy=0.0005216651269020373 vz=7.712448739774162e-05>
# <rebound.Particle object, m=1.6601141530543488e-07 x=-0.023291658427882382 y=0.3152976584963577 z=0.027128266499068132 vx=-12.314341706188948 vy=-0.36109763602354505 vz=1.0999425156951566>
# <rebound.Particle object, m=2.4478382877847715e-06 x=-0.43013718513207744 y=-0.5758985721446856 z=0.016701037975996712 vx=5.897806086540624 vy=-4.409427516933958 vz=-0.40095320958929487>
# ...

# %%
print(sim.particles[5].orbit.e)
print(sim.particles[5].orbit.P)
print(sim.particles[5].orbit.a)

# %%
print(sim.particles[5].x,sim.particles[5].y,sim.particles[5].z)
sim.t = 0
sim.move_to_com()
print(sim.particles[0].x,sim.particles[0].y,sim.particles[0].z)
np.zeros
Noutputs = 30
years = 300
orbits = np.zeros((3,Noutputs))
positions = np.zeros((3,Noutputs))
times = np.linspace(0.,years, Noutputs)
for i,time in enumerate(times):
    sim.integrate(time)
    #print(sim.calculate_orbits()[0])
    print(sim.particles[0].x,sim.particles[0].y,sim.particles[0].z)
    orbits[0][i] = sim.particles[5].orbit.P
    orbits[1][i] = sim.particles[5].orbit.e
    orbits[2][i] = sim.particles[5].orbit.a
    positions[0][i] = sim.particles[5].x
    positions[1][i] = sim.particles[5].y
    positions[2][i] = sim.particles[5].z

# %%
#Data from horizons
ecc = [5.148075885040082e-01, 5.149256868342506e-01,

5.149518631325408e-01,

5.148870577157909e-01,

5.150078719226753e-01,

5.150045499979038e-01,

5.149321949390553e-01,

5.150129216925604e-01,

5.150930852896169e-01,

5.150482712369111e-01,

]

# %%
#egrep ' X =' horizons_results.txt | cut -c 6-26
#egrep ' X =' horizons_results.txt | cut -c 6-26 | awk '{print $0, ","}'

# x = [5.748962805576951E-01
# 7.486462468959210E-01
# 8.968618396152149E-01
# 1.006234936434692E+00
# 1.094235033273400E+00
fig = plt.figure(figsize=(12,3))
ax = plt.subplot(111)
ax.set_xlabel("time [yrs]")
ax.set_ylabel("eccentricity")

plt.plot(times, orbits[1]);
plt.plot(times, ecc);

# %%
distance = np.sqrt(np.square(x-positions[0])+np.square(y-positions[1])+np.square(z-positions[2]))

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(12,3))
ax = plt.subplot(111)
ax.set_xlabel("time [yrs]")
ax.set_ylabel("distance [AU]")
plt.plot(times,distance)
print(sim.t)

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(12,3))
ax = plt.subplot(111)
ax.set_xlabel("time [yrs]")
ax.set_ylabel("distance [AU]")
plt.plot(times,z)
plt.plot(times,positions[2])
print(sim.t)

# %%
Noutputs = 37255/5
year = 7452/(365.25/5) # One year in units where G=1
times = np.linspace(0.,year, Noutputs)
x = np.zeros((2,Noutputs))
y = np.zeros((2,Noutputs))
z = np.zeros((2,Noutputs))
sim.integrator = "ias15" # IAS15 is the default integrator, so we actually don't need this line
sim.move_to_com()        # We always move to the center of momentum frame before an integration
ps = sim.particles       # ps is now an array of pointers and will change as the simulation runs

for i,time in enumerate(times):
    if i % 10000 ==0:
        print(i)
    sim.integrate(time)
    x[0][i] = ps[3].x   # Earth This stores the data which allows us to plot it later
    y[0][i] = ps[3].y
    z[0][i] = ps[3].z
    x[1][i] = ps[5].x   # Cruithne
    y[1][i] = ps[5].y
    z[1][i] = ps[5].z
# Out:
# 0

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(12,3))
ax = plt.subplot(111)
ax.set_xlabel("time [yrs]")
ax.set_ylabel("distance [AU]")
distance = np.sqrt(np.square(x[0]-x[1])+np.square(y[0]-y[1])+np.square(z[0]-z[1]))
k = 100000+1000*7
plt.plot(times, distance);
closeencountertime = times[np.argmin(distance)]
print("Minimum distance (%f AU) occured at time: %f years." % (np.min(distance),closeencountertime))
# Out:
# <img src="data:image/png;base64,..." width="1200">
# Minimum distance (0.558527 AU) occured at time: 0.665298 years.

# %%
Xpos = np.loadtxt("X_100years.txt")
Ypos = np.loadtxt("Y_100years.txt")
Zpos = np.loadtxt("Z_100years.txt")
print(Ypos.shape)
print(Xpos.shape)
print(Zpos.shape)
# Out:
# (7452,)
# (7452,)
# (7452,)

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(12,3))
ax = plt.subplot(111)
ax.set_xlabel("time [yrs]")
ax.set_ylabel("distance [AU]")
distance2 = np.sqrt(np.square(Xpos)+np.square(Ypos)+np.square(Zpos))
plt.plot(times, distance-distance2);
print(distance[1]-distance2[1])
#plt.plot(times, distance2);
closeencountertime = times[np.argmin(distance)]
print("Minimum distance (%f AU) occured at time: %f years." % (np.min(distance),closeencountertime))
# Out:
# <img src="data:image/png;base64,..." width="1200">
# -2.4436452861209546e-11
# Minimum distance (0.558527 AU) occured at time: 0.665298 years.
