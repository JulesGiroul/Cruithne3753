# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.animation as animation
x = np.load("X_positions_100_000.npy")
y = np.load("Y_positions_100_000.npy")
z = np.load("Z_positions_100_000.npy")
print(x[0,0])
# Out:
# -0.7113045602813076

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)

x_pos = [x[0,0],x[1,0]]
y_pos = [y[0,0],y[1,0]]
line_x = []
line_y = []
scat = ax.scatter(x_pos,  \
                  y_pos,   \
                  c=['g','b'], marker="o", s=[20,100])
line, = ax.plot(line_x,line_y)

def update(frame):
    i = frame + 176300
    x_pos = [x[0,i],x[1,i]]
    y_pos = [y[0,i],y[1,i]]
    scat.set_offsets(np.c_[x_pos,y_pos])
    
   # line_x.append(x[0,frame])
    #line_y.append(y[0,frame])
    line.set_data(line_x,line_y)
    return scat, line,


ani = animation.FuncAnimation(fig, update, blit=True,interval=500)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
